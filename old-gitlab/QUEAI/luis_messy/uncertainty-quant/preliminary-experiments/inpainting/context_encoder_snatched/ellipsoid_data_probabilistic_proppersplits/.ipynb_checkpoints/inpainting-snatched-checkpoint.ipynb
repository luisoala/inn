# %%
from context_encoder_WORKING import *
# Out:
# Using TensorFlow backend.

# %%
context_encoder = ContextEncoder()
context_encoder.train(epochs=2000, batch_size=128, sample_interval=50)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 16385
# =================================================================
# Total params: 387,841
# Trainable params: 386,945
# Non-trainable params: 896
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   320         input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 512)    66048       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 512)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  589952      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         activation_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 1)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 1)    0           activation_4[0][0]
# ==================================================================================================
# Total params: 825,282
# Trainable params: 824,450
# Non-trainable params: 832
# __________________________________________________________________________________________________
# Getting and resizing train images and masks ...
# Done with #  0
# Done with #  500
# Done with #  1000
# Done with #  1500
# 0.8915083543144884
# -0.8851911192492561
# Getting and resizing val images and masks ...
# Done with #  0
# Getting and resizing test images and masks ...
# Done with #  0
# /home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 12323.003
# 20.418072
# 4.025075e-06
# 0 [D loss: 0.009425, acc: 100.00%] [G loss: -668.195801, exp-dist-loss: -668.868347]
# val-results
# [G loss: -4169.945801, exp-dist-loss: -4174.120117]
# 0.36340117
# 9.085443e-06
# 2.1522897e-07
# 50 [D loss: 0.000150, acc: 100.00%] [G loss: -4569.205566, exp-dist-loss: -4573.789062]
# val-results
# [G loss: -7185.678711, exp-dist-loss: -7192.872070]
# 0.088790104
# 3.9997967e-06
# 4.565281e-08
# 100 [D loss: 0.000127, acc: 100.00%] [G loss: -4586.138184, exp-dist-loss: -4590.745117]
# val-results
# [G loss: -7194.703613, exp-dist-loss: -7201.906250]
# 0.04243382
# 3.889301e-06
# 1.1910246e-08
# 150 [D loss: 0.000188, acc: 100.00%] [G loss: -4594.460938, exp-dist-loss: -4599.071777]
# val-results
# [G loss: -7184.925293, exp-dist-loss: -7192.118164]
# 0.024804082
# 3.280393e-06
# 3.13265e-09
# 200 [D loss: 0.000315, acc: 100.00%] [G loss: -4601.715332, exp-dist-loss: -4606.336914]
# val-results
# [G loss: -7188.666992, exp-dist-loss: -7195.863281]
# 0.016135521
# 3.1724421e-06
# 5.14944e-10
# 250 [D loss: 0.000096, acc: 100.00%] [G loss: -4608.828613, exp-dist-loss: -4613.457520]
# val-results
# [G loss: -7185.258789, exp-dist-loss: -7192.451660]
# 0.010124676
# 6.866245e-06
# 1.8015038e-10
# 300 [D loss: 0.000041, acc: 100.00%] [G loss: -4613.877441, exp-dist-loss: -4618.512207]
# val-results
# [G loss: -7177.959961, exp-dist-loss: -7185.145508]
# 0.007143127
# 1.662286e-06
# 4.5291246e-11
# 350 [D loss: 0.000038, acc: 100.00%] [G loss: -4617.675293, exp-dist-loss: -4622.310547]
# val-results
# [G loss: -7176.580078, exp-dist-loss: -7183.764160]
# 0.004610599
# 3.2741862e-06
# 8.866238e-12
# 400 [D loss: 0.002223, acc: 100.00%] [G loss: -4617.875488, exp-dist-loss: -4622.506348]
# val-results
# [G loss: -7169.697266, exp-dist-loss: -7176.874512]
# 0.003514228
# 4.141245e-06
# 1.3894932e-12
# 450 [D loss: 0.000096, acc: 100.00%] [G loss: -4622.624023, exp-dist-loss: -4627.263672]
# val-results
# [G loss: -7176.725098, exp-dist-loss: -7183.909180]
# 0.0025375206
# 1.0432328e-05
# 2.458982e-12
# 500 [D loss: 0.000376, acc: 100.00%] [G loss: -4627.196777, exp-dist-loss: -4631.842285]
# val-results
# [G loss: -7175.646973, exp-dist-loss: -7182.829590]
# 0.0016526497
# 1.536478e-06
# 1.9586427e-13
# 550 [D loss: 0.000180, acc: 100.00%] [G loss: -4624.977051, exp-dist-loss: -4629.621094]
# val-results
# [G loss: -7177.389160, exp-dist-loss: -7184.573730]
# 0.0011815219
# 1.3205815e-06
# 1.5348798e-14
# 600 [D loss: 0.000035, acc: 100.00%] [G loss: -4630.056152, exp-dist-loss: -4634.706055]
# val-results
# [G loss: -7176.187012, exp-dist-loss: -7183.370117]
# 0.0009059876
# 3.9768574e-06
# 1.1595961e-14
# 650 [D loss: 0.000028, acc: 100.00%] [G loss: -4631.071777, exp-dist-loss: -4635.722656]
# val-results
# [G loss: -7174.990234, exp-dist-loss: -7182.172363]
# 0.0006477777
# 1.5247508e-06
# 1.4289963e-14
# 700 [D loss: 0.000008, acc: 100.00%] [G loss: -4628.579102, exp-dist-loss: -4633.227051]
# val-results
# [G loss: -7157.883301, exp-dist-loss: -7165.048340]
# 0.00042279702
# 3.1767897e-06
# 2.8260807e-15
# 750 [D loss: 0.000036, acc: 100.00%] [G loss: -4629.791016, exp-dist-loss: -4634.439941]
# val-results
# [G loss: -7169.763672, exp-dist-loss: -7176.940430]
# 0.0003420451
# 2.6629277e-06
# 3.055009e-16
# 800 [D loss: 0.000024, acc: 100.00%] [G loss: -4630.729980, exp-dist-loss: -4635.380371]
# val-results
# [G loss: -7169.834473, exp-dist-loss: -7177.011230]
# 0.00023427431
# 1.2946724e-06
# 1.2552226e-17
# 850 [D loss: 0.000004, acc: 100.00%] [G loss: -4634.510742, exp-dist-loss: -4639.165527]
# val-results
# [G loss: -7173.486816, exp-dist-loss: -7180.667480]
# 0.00016553298
# 1.3031677e-06
# 1.9057251e-16
# 900 [D loss: 0.000064, acc: 100.00%] [G loss: -4634.237793, exp-dist-loss: -4638.892090]
# val-results
# [G loss: -7164.766113, exp-dist-loss: -7171.937988]
# 0.00012543556
# 6.7993466e-07
# 4.366889e-18
# 950 [D loss: 0.000011, acc: 100.00%] [G loss: -4634.944336, exp-dist-loss: -4639.600098]
# val-results
# [G loss: -7169.088867, exp-dist-loss: -7176.265137]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-69648c4eab1b> in <module>()
#       1 context_encoder = ContextEncoder()
# ----> 2 context_encoder.train(epochs=2000, batch_size=128, sample_interval=50)
#
# ~/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsoid_data_probabilistic_proppersplits/context_encoder_WORKING.py in train(self, epochs, batch_size, sample_interval)
#     305                 # ---------------------
#     306
# --> 307                 g_loss = self.combined.train_on_batch(masked_imgs, [missing_parts, valid])
#     308
#     309             # Plot the progress
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
context_encoder.save_model()
