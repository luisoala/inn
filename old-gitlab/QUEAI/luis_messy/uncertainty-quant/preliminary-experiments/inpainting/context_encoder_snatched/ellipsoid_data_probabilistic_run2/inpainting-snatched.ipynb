# %%
from context_encoder_WORKING import *
# Out:
# Using TensorFlow backend.

# %%
context_encoder = ContextEncoder()
context_encoder.train(epochs=30000, batch_size=128, sample_interval=500)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 16385
# =================================================================
# Total params: 387,841
# Trainable params: 386,945
# Non-trainable params: 896
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   320         input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 512)    66048       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 512)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  589952      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         activation_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 1)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 1)    0           lambda_1[0][0]
# ==================================================================================================
# Total params: 825,282
# Trainable params: 824,450
# Non-trainable params: 832
# __________________________________________________________________________________________________
# Getting and resizing train images and masks ...
# Done with #  0
# Done with #  500
# Done with #  1000
# Done with #  1500
# 0.8915083543144884
# -0.8851911192492561
# /home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 131731.19
# 1.0393143
# 0.97987896
# 0 [D loss: 1.782766, acc: 28.52%] [G loss: 21.740715, exp-dist-loss: 21.761730]
# 16528.707
# 92.5726
# 1.3997538e-05
# 200 [D loss: 0.001342, acc: 100.00%] [G loss: -3923.352051, exp-dist-loss: -3927.284668]
# 1.0719962
# 3.9741073e-05
# 8.450528e-07
# 400 [D loss: 0.000192, acc: 100.00%] [G loss: -4552.332031, exp-dist-loss: -4556.892578]
# 0.3769269
# 1.08195645e-05
# 3.0625492e-07
# 600 [D loss: 0.000145, acc: 100.00%] [G loss: -4571.962402, exp-dist-loss: -4576.544922]
# 0.20032535
# 6.6078655e-06
# 1.501877e-07
# 800 [D loss: 0.000101, acc: 100.00%] [G loss: -4578.030273, exp-dist-loss: -4582.618652]
# 0.13930354
# 4.069932e-06
# 7.868443e-08
# 1000 [D loss: 0.000096, acc: 100.00%] [G loss: -4583.850098, exp-dist-loss: -4588.449219]
# 0.09629195
# 7.3978185e-06
# 6.3248116e-08
# 1200 [D loss: 0.000039, acc: 100.00%] [G loss: -4585.955566, exp-dist-loss: -4590.556641]
# 0.07053681
# 2.791845e-06
# 3.83304e-08
# 1400 [D loss: 0.000177, acc: 100.00%] [G loss: -4586.756836, exp-dist-loss: -4591.364258]
# 2.2914784e-22
# 16600 [D loss: 0.000000, acc: 100.00%] [G loss: -4635.856934, exp-dist-loss: -4640.513672]
# 2.488261e-05
# 1.2315037e-07
# 1.6953077e-19
# 16800 [D loss: 0.000000, acc: 100.00%] [G loss: -4636.029785, exp-dist-loss: -4640.686523]
# 2.2954075e-05
# 1.6253803e-07
# 2.0536713e-19
# 17000 [D loss: 0.000001, acc: 100.00%] [G loss: -4635.657715, exp-dist-loss: -4640.313965]
# 1.6598928e-05
# 1.3139442e-07
# 1.3414314e-19
# 17200 [D loss: 0.000000, acc: 100.00%] [G loss: -4635.982422, exp-dist-loss: -4640.639160]
# 1.7218712e-05
# 1.7084176e-07
# 2.1624624e-23
# 17400 [D loss: 0.000000, acc: 100.00%] [G loss: -4637.032227, exp-dist-loss: -4641.689941]
# 1.5509502e-05
# 4.3432317e-07
# 4.4597095e-21
# 17600 [D loss: 0.000000, acc: 100.00%] [G loss: -4635.161621, exp-dist-loss: -4639.817383]
# 1.759285e-05
# 2.1945785e-07
# 5.8630985e-27
# 17800 [D loss: 0.000001, acc: 100.00%] [G loss: -4635.780273, exp-dist-loss: -4640.436523]
# 1.5539865e-05
# 4.9766624e-07
# 6.799327e-24
# 18000 [D loss: 0.000001, acc: 100.00%] [G loss: -4636.886719, exp-dist-loss: -4641.544434]
# 1.4223451e-05
# 8.786358e-08
# 5.0082575e-22
# 18200 [D loss: 0.000000, acc: 100.00%] [G loss: -4634.540527, exp-dist-loss: -4639.195801]
# 1.4327979e-05
# 1.08054266e-07
# 1.5817051e-23
# 18400 [D loss: 0.000000, acc: 100.00%] [G loss: -4638.542969, exp-dist-loss: -4643.202148]
# 1.1789105e-05
# 9.59937e-08
# 1.6510386e-21
# 18600 [D loss: 0.000000, acc: 100.00%] [G loss: -4637.267578, exp-dist-loss: -4641.925781]
# 2.0515436e-05
# 9.83797e-07
# 2.884338e-23
# 18800 [D loss: 0.000001, acc: 100.00%] [G loss: -4598.909180, exp-dist-loss: -4603.528809]
# 1.5097685e-05
# 1.7380474e-07
# 1.8555414e-28
# 19000 [D loss: 0.000000, acc: 100.00%] [G loss: -4638.475098, exp-dist-loss: -4643.134277]
# 2.4572622e-05
# 1.8764834e-07
# 2.0629325e-23
# 19200 [D loss: 0.000000, acc: 100.00%] [G loss: -4634.108887, exp-dist-loss: -4638.763672]
# 1.5021863e-05
# 3.350519e-07
# 4.0140706e-28
# 19400 [D loss: 0.000000, acc: 100.00%] [G loss: -4636.903320, exp-dist-loss: -4641.561035]
# nan
# nan
# nan
# 19600 [D loss: 7.971192, acc: 0.00%] [G loss: inf, exp-dist-loss: inf]
# /home/oala/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /home/oala/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# nan
# nan
# nan
# 19800 [D loss: 7.971192, acc: 0.00%] [G loss: inf, exp-dist-loss: inf]
# nan
# nan
# nan
# 20000 [D loss: 7.971192, acc: 0.00%] [G loss: inf, exp-dist-loss: inf]
# nan
# nan
# nan
# 20200 [D loss: 7.971192, acc: 0.00%] [G loss: inf, exp-dist-loss: inf]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d6419000fc78> in <module>()
#       1 context_encoder = ContextEncoder()
# ----> 2 context_encoder.train(epochs=30000, batch_size=128, sample_interval=500)
#
# ~/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py in train(self, epochs, batch_size, sample_interval)
#     265             # ---------------------
#     266
# --> 267             g_loss = self.combined.train_on_batch(masked_imgs, [missing_parts, valid])
#     268
#     269             # Plot the progress
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1218             ins = x + y + sample_weights
#    1219         self._make_train_function()
# -> 1220         outputs = self.train_function(ins)
#    1221         if len(outputs) == 1:
#    1222             return outputs[0]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2665                     'In order to feed symbolic tensors to a Keras model '
#    2666                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2667             return self._legacy_call(inputs)
#    2668
#    2669
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2647         session = get_session()
#    2648         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2649                               **self.session_kwargs)
#    2650         return updated[:len(self.outputs)]
#    2651
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
context_encoder.save_model()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-cdeacd8c714d> in <module>()
# ----> 1 context_encoder.save_model()
#
# ~/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py in save_model(self)
#     314             model.save_weights(options['file_weight'])
#     315
# --> 316         save(self.generator, "generator")
#     317         save(self.discriminator, "discriminator")
#     318
#
# ~/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py in save(model, model_name)
#     310             options = {"file_arch": model_path,
#     311                         "file_weight": weights_path}
# --> 312             json_string = model.to_json()
#     313             open(options['file_arch'], 'w').write(json_string)
#     314             model.save_weights(options['file_weight'])
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/network.py in to_json(self, **kwargs)
#    1221             raise TypeError('Not JSON Serializable:', obj)
#    1222
# -> 1223         model_config = self._updated_config()
#    1224         return json.dumps(model_config, default=get_json_type, **kwargs)
#    1225
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/network.py in _updated_config(self)
#    1188         from .. import __version__ as keras_version
#    1189
# -> 1190         config = self.get_config()
#    1191         model_config = {
#    1192             'class_name': self.__class__.__name__,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/network.py in get_config(self)
#     940             model_outputs.append([layer.name, new_node_index, tensor_index])
#     941         config['output_layers'] = model_outputs
# --> 942         return copy.deepcopy(config)
#     943
#     944     @classmethod
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     218
#     219 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 220     y = [deepcopy(a, memo) for a in x]
#     221     # We're not going to put the tuple in the memo, but it's still important we
#     222     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/anaconda3/lib/python3.6/copy.py in <listcomp>(.0)
#     218
#     219 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 220     y = [deepcopy(a, memo) for a in x]
#     221     # We're not going to put the tuple in the memo, but it's still important we
#     222     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     218
#     219 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 220     y = [deepcopy(a, memo) for a in x]
#     221     # We're not going to put the tuple in the memo, but it's still important we
#     222     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/anaconda3/lib/python3.6/copy.py in <listcomp>(.0)
#     218
#     219 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 220     y = [deepcopy(a, memo) for a in x]
#     221     # We're not going to put the tuple in the memo, but it's still important we
#     222     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     167                     reductor = getattr(x, "__reduce_ex__", None)
#     168                     if reductor:
# --> 169                         rv = reductor(4)
#     170                     else:
#     171                         reductor = getattr(x, "__reduce__", None)
#
# TypeError: can't pickle _thread.lock objects
