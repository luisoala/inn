# %%
from context_encoder_WORKING import *
# Out:
# Using TensorFlow backend.

# %%
context_encoder = ContextEncoder()
context_encoder.train(epochs=30000, batch_size=128, sample_interval=500)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 16385
# =================================================================
# Total params: 387,841
# Trainable params: 386,945
# Non-trainable params: 896
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   320         input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 512)    66048       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 512)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  589952      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         activation_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 1)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 1)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 1)    0           lambda_1[0][0]
# ==================================================================================================
# Total params: 825,282
# Trainable params: 824,450
# Non-trainable params: 832
# __________________________________________________________________________________________________
# Getting and resizing train images and masks ...
# Done with #  0
# Done with #  500
# Done with #  1000
# Done with #  1500
# 0.8915083543144884
# -0.8851911192492561
# /home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# ResourceExhaustedError: OOM when allocating tensor with shape[128,256,8,8] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training/Adam/gradients/sequential_1/batch_normalization_3/FusedBatchNorm_grad/FusedBatchNormGrad = FusedBatchNormGrad[T=DT_FLOAT, _class=["loc:@sequential_1/batch_normalization_3/FusedBatchNorm"], data_format="NHWC", epsilon=0.001, is_training=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training/Adam/gradients/sequential_1/batch_normalization_3/cond/Switch_1_grad/cond_grad, sequential_1/leaky_re_lu_3/LeakyRelu/Maximum, batch_normalization_3/gamma/read, sequential_1/batch_normalization_3/FusedBatchNorm:3, sequential_1/batch_normalization_3/FusedBatchNorm:4)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-2-d6419000fc78> in <module>()
#       1 context_encoder = ContextEncoder()
# ----> 2 context_encoder.train(epochs=30000, batch_size=128, sample_interval=500)
#
# ~/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py in train(self, epochs, batch_size, sample_interval)
#     257
#     258             # Train the discriminator
# --> 259             d_loss_real = self.discriminator.train_on_batch(missing_parts, valid)
#     260             d_loss_fake = self.discriminator.train_on_batch(out_mean, fake)
#     261             d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1218             ins = x + y + sample_weights
#    1219         self._make_train_function()
# -> 1220         outputs = self.train_function(ins)
#    1221         if len(outputs) == 1:
#    1222             return outputs[0]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2665                     'In order to feed symbolic tensors to a Keras model '
#    2666                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2667             return self._legacy_call(inputs)
#    2668
#    2669
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2647         session = get_session()
#    2648         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2649                               **self.session_kwargs)
#    2650         return updated[:len(self.outputs)]
#    2651
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[128,256,8,8] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training/Adam/gradients/sequential_1/batch_normalization_3/FusedBatchNorm_grad/FusedBatchNormGrad = FusedBatchNormGrad[T=DT_FLOAT, _class=["loc:@sequential_1/batch_normalization_3/FusedBatchNorm"], data_format="NHWC", epsilon=0.001, is_training=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training/Adam/gradients/sequential_1/batch_normalization_3/cond/Switch_1_grad/cond_grad, sequential_1/leaky_re_lu_3/LeakyRelu/Maximum, batch_normalization_3/gamma/read, sequential_1/batch_normalization_3/FusedBatchNorm:3, sequential_1/batch_normalization_3/FusedBatchNorm:4)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'training/Adam/gradients/sequential_1/batch_normalization_3/FusedBatchNorm_grad/FusedBatchNormGrad', defined at:
#   File "/home/oala/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/oala/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-d6419000fc78>", line 2, in <module>
#     context_encoder.train(epochs=30000, batch_size=128, sample_interval=500)
#   File "/home/oala/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py", line 259, in train
#     d_loss_real = self.discriminator.train_on_batch(missing_parts, valid)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/training.py", line 1219, in train_on_batch
#     self._make_train_function()
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/training.py", line 497, in _make_train_function
#     loss=self.total_loss)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/optimizers.py", line 445, in get_updates
#     grads = self.get_gradients(loss, params)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/optimizers.py", line 78, in get_gradients
#     grads = K.gradients(loss, params)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2703, in gradients
#     return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 609, in gradients
#     grad_scope, op, func_call, lambda: grad_fn(op, *out_grads))
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 375, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 609, in <lambda>
#     grad_scope, op, func_call, lambda: grad_fn(op, *out_grads))
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py", line 798, in _FusedBatchNormGrad
#     return _BaseFusedBatchNormGrad(op, False, *grad)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py", line 775, in _BaseFusedBatchNormGrad
#     is_training=is_training)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 2341, in fused_batch_norm_grad
#     name=name)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ...which was originally created as op 'sequential_1/batch_normalization_3/FusedBatchNorm', defined at:
#   File "/home/oala/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# [elided 16 identical lines from previous traceback]
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-d6419000fc78>", line 1, in <module>
#     context_encoder = ContextEncoder()
#   File "/home/oala/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py", line 59, in __init__
#     self.discriminator = self.build_discriminator()
#   File "/home/oala/Documents/experiments-hhi/uncertainty-quant/preliminary-experiments/context_encoder_snatched/ellipsiod_data_probabilistic_run2/context_encoder_WORKING.py", line 162, in build_discriminator
#     validity = model(img)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py", line 460, in __call__
#     output = self.call(inputs, **kwargs)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/network.py", line 573, in call
#     output_tensors, _, _ = self.run_internal_graph(inputs, masks)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/engine/network.py", line 730, in run_internal_graph
#     output_tensors = to_list(layer.call(computed_tensor, **kwargs))
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/layers/normalization.py", line 183, in call
#     epsilon=self.epsilon)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 1841, in normalize_batch_in_training
#     epsilon=epsilon)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 1816, in _fused_normalize_batch_in_training
#     data_format=tf_data_format)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py", line 881, in fused_batch_norm
#     name=name)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 2254, in _fused_batch_norm
#     is_training=is_training, name=name)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "/home/oala/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[128,256,8,8] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training/Adam/gradients/sequential_1/batch_normalization_3/FusedBatchNorm_grad/FusedBatchNormGrad = FusedBatchNormGrad[T=DT_FLOAT, _class=["loc:@sequential_1/batch_normalization_3/FusedBatchNorm"], data_format="NHWC", epsilon=0.001, is_training=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training/Adam/gradients/sequential_1/batch_normalization_3/cond/Switch_1_grad/cond_grad, sequential_1/leaky_re_lu_3/LeakyRelu/Maximum, batch_normalization_3/gamma/read, sequential_1/batch_normalization_3/FusedBatchNorm:3, sequential_1/batch_normalization_3/FusedBatchNorm:4)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
context_encoder.save_model()
